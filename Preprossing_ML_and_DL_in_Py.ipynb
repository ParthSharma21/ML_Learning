# %%
pwd
# Out:
# 'C:\\Users\\parth sharma\\anaconda3\\Scripts\\Python\\Machine_Learning_&_Deep_Learning_in_Python_&_R'

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('C://Users//parth sharma//anaconda3//Scripts//Python//Machine_Learning_&_Deep_Learning_in_Python_&_R//House_Price.csv',header=0)

# %%
df.head() #df = Data Frame
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x='n_hot_rooms',y='price',data=df)

# %%
sns.jointplot(x='rainfall',y='price',data=df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x='airport',data=df)

# %%
sns.countplot(x='waterbody',data=df)

# %%
sns.countplot(x='bus_ter',data=df)

# %% [markdown]
# Observations:
# 1. Missing var in 'n_hos_bed's.
# 2. skewness or outlier in 'crime_rate'. #we don't know if it's skewness or an outlier.
# 3. Outliers in 'n_hot_rooms' and 'rainfall'.
# 4. 'bus_ter' has only 'Yes' values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
uv= np.percentile(df.n_hot_rooms,[99])[0] #upper value / limit

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df[(df.n_hot_rooms>3*uv)]=3*uv

# %%
sns.scatterplot(x='n_hot_rooms',y='price',data=df)

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#         price  crime_rate  resid_area  air_qual  room_num       age     dist1  \
# 2    46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
# 166  50.00000     2.01019    49.58000   0.60500   7.92900  96.20000   2.11000
# 204  50.00000     0.02009    32.68000   0.41610   8.03400  31.90000   5.41000
# 267  50.00000     0.57834    33.97000   0.57500   8.29700  67.00000   2.60000
# 369  50.00000     5.66998    48.10000   0.63100   6.68300  96.80000   1.55000
# 423  46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
#
#         dist2     dist3     dist4  teachers  poor_prop  airport  n_hos_beds  \
# 2    46.19856  46.19856  46.19856  46.19856   46.19856  46.1986    46.19856
# 166   1.91000   2.31000   1.86000  25.30000    3.70000      YES     8.30000
# 204   4.80000   5.28000   4.99000  25.30000    2.88000      YES     8.90000
# 267   2.13000   2.43000   2.52000  27.00000    7.44000      YES     8.00000
# ...

# %% [markdown]
# ^^^^ here the values of n_hot_room outliers is converted to 3*uv i.e. 46.19856 ^^^^

# %%
lv=np.percentile(df.rainfall,[1])[0]

# %%
lv
# Out:
# 20.0

# %%
df[(df.rainfall<0.3*lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None       3.0     YES  0.044019

# %%
df[(df.rainfall<0.3*lv)]=0.3*lv

# %%
df[(df.rainfall<0.3*lv)]
# Out:
# Empty DataFrame
# Columns: [price, crime_rate, resid_area, air_qual, room_num, age, dist1, dist2, dist3, dist4, teachers, poor_prop, airport, n_hos_beds, n_hot_rooms, waterbody, rainfall, bus_ter, parks]
# Index: []

# %%
sns.scatterplot(x='rainfall',y='price',data=df)

# %%
for i in df.columns:                          #                impo
  lv=np.percentile(df[i],[1])[0]
  df[(df[i]<0.3*lv)]=0.3*lv 
  uv= np.percentile(df[i],[99])[0] 
  df[(df[i]>3*uv)]=3*uv                       # A loop to remove  all the outliers
    
    
#This is giving error but i think thatt if i take the dummy vars first and then all will be in numerical format then it might work
# Out:
# 'for i in df.columns:                          #impo\n  lv=np.percentile(df[i],[1])[0]\n  df[(df[i]<0.3*lv)]=0.3*lv \n  uv= np.percentile(df[i],[99])[0] \n  df[(df[i]>3*uv)]=3*uv                       # A loop to remove  all the outliers'

# %%
sns.jointplot(x='crime_rate',y='price',data=df)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    3.793719   41.082702    0.746049    6.440235   68.416595
# std      9.303248    9.004149    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006320    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082268   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.262660   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    3.695990   48.100000    0.629250    6.628000   94.075000
# max     50.000000   88.976200   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.144283    3.802326    4.132346    3.792860   21.613631   12.774994
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    float64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds=df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   teachers     506 non-null    float64
#  7   poor_prop    506 non-null    float64
#  8   airport      506 non-null    object
#  9   n_hos_beds   506 non-null    float64
#  10  n_hot_rooms  506 non-null    float64
#  11  waterbody    506 non-null    object
#  12  rainfall     506 non-null    float64
#  13  bus_ter      506 non-null    object
#  14  parks        506 non-null    float64
#  15  avg_dist     506 non-null    float64
# dtypes: float64(13), object(3)
# memory usage: 63.4+ KB

# %%
# df = df.fillna(df.mean())  #to fill all the missing vals in df with 'mean', but we may want mode/0... so we do it individual vars like just above.

# %%
sns.jointplot(x='crime_rate',y='price',data=df)

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x='crime_rate',y='price',data=df)

# %%
#df.crime_rate = np.exp(df.crime_rate-1)

# %%
#sns.jointplot(x='crime_rate',y='price',data=df)

# %%
#df.crime_rate = np.array(map(lambda x: 1/(x+1),df.crime_rate))#np.exp(df.crime_rate-1)

# %%
#sns.jointplot(x='crime_rate',y='price',data=df)

# %%
df['avg_dist']=(df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    0.828063   41.082702    0.746049    6.440235   68.416595
# std      9.303248    1.039027    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.079058   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.233220   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    1.546709   48.100000    0.629250    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.144283    3.802326    4.132346    3.792860   21.613631   12.774994
# ...

# %%
del df['dist1']

# %%
del df['dist2']

# %%
del df['dist3']

# %%
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    0.828063   41.082702    0.746049    6.440235   68.416595
# std      9.303248    1.039027    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.079058   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.233220   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    1.546709   48.100000    0.629250    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.613631   12.774994    8.050717    12.855700   39.237939
# ...

# %%
del df["bus_ter"] #since, its not providing any useful info to our model

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df=pd.get_dummies(df)

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...  airport_6.0  airport_46.19856  \
# 0    4.98000     5.48000     11.19200  ...            0                 0
# 1    9.14000     7.33200     12.17280  ...            0                 0
# 2   46.19856    46.19856     46.19856  ...            0                 1
# 3    2.94000     9.26800     11.26720  ...            0                 0
# 4    5.33000     8.82400     11.28960  ...            0                 0
#
# ...

# %%
del df['airport_46.19856']

# %%
del df['airport_6.0']

# %%
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
del df['waterbody_6.0']

# %%
del df['waterbody_46.19856']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000     0.00632    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000     0.02731    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000     0.03237    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000     0.06905    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...      parks  avg_dist  airport_6.0  \
# 0    4.98000     5.48000     11.19200  ...   0.049347   4.08750            0
# 1    9.14000     7.33200     12.17280  ...   0.046146   4.96750            0
# 2   46.19856    46.19856     46.19856  ...  46.198560  46.19856            0
# 3    2.94000     9.26800     11.26720  ...   0.047151   6.06500            0
# 4    5.33000     8.82400     11.28960  ...   0.039474   6.06250            0
#
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.422527   -0.438254  0.135889
# crime_rate               -0.422527    1.000000    0.628175  0.214846
# resid_area               -0.438254    0.628175    1.000000  0.056893
# air_qual                  0.135889    0.214846    0.056893  1.000000
# room_num                  0.338999    0.100646   -0.057325  0.955151
# age                      -0.368388    0.531227    0.644261 -0.028409
# teachers                  0.501262   -0.209088   -0.211118  0.534238
# poor_prop                -0.648314    0.620905    0.584021  0.301988
# n_hos_beds                0.195533    0.152706    0.048358  0.846446
# n_hot_rooms               0.143055    0.180176    0.046378  0.765458
# rainfall                 -0.029800    0.079964    0.083449  0.028624
# parks                     0.150908    0.189581    0.028012  0.999296
# avg_dist                  0.273978   -0.210713   -0.397332  0.764200
# ...

# %%
del df['parks']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0    4.98000     5.48000     11.19200  23.00000   4.08750            1
# 1    9.14000     7.33200     12.17280  42.00000   4.96750            0
# 2   46.19856    46.19856     46.19856  46.19856  46.19856            0
# 3    2.94000     9.26800     11.26720  45.00000   6.06500            1
# 4    5.33000     8.82400     11.28960  55.00000   6.06250            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
import statsmodels.api as sn

# %%
x = sn.add_constant(df['room_num'])

# %%
lm = sn.OLS(df['price'],x).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     65.44
# Date:                Sat, 03 Oct 2020   Prob (F-statistic):           4.50e-15
# Time:                        20:32:06   Log-Likelihood:                -1815.2
# No. Observations:                 506   AIC:                             3634.
# Df Residuals:                     504   BIC:                             3643.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.7707      1.040     14.201      0.000      12.727      16.814
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['price']

# %%
x = df[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# 14.770704175408277 [1.2114491]

# %%
lm2.predict(x)  # to predict the value of y(price) depending on the Linear Model that we generated

# %%
help(sns.jointplot)  # we use 'kind' k.w. here as 'reg' to print a regression line, by default its scatter
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot(x=df['room_num'],y=df['price'],data=df,kind='reg')

# %% [markdown]
#                                            MULTIPLE LINEAR REGG.

# %%
from sklearn.linear_model import LinearRegression 
import statsmodels.api as sn

# %%
x_multi = df.drop('price',axis=1)

# %%
x_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num       age  teachers  poor_prop  \
# 0    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000    4.98000
# 1    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000    9.14000
# 2    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856   46.19856
# 3    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000    2.94000
# 4    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000    5.33000
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_Lake  \
# 0     5.48000     11.19200  23.00000   4.08750            1               0
# 1     7.33200     12.17280  42.00000   4.96750            0               1
# 2    46.19856     46.19856  46.19856  46.19856            0               0
# 3     9.26800     11.26720  45.00000   6.06500            1               1
# 4     8.82400     11.28960  55.00000   6.06250            0               1
#
#    waterbody_Lake and River  waterbody_River
# ...

# %%
y_multi = df['price']

# %%
y_multi.head()
# Out:
# 0    24.00000
# 1    21.60000
# 2    46.19856
# 3    33.40000
# 4    36.20000
# Name: price, dtype: float64

# %%
x_multi_cons = sn.add_constant(x_multi)

# %%
x_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0    1.0    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1    1.0    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2    1.0    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3    1.0    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4    1.0    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0    4.98000     5.48000     11.19200  23.00000   4.08750            1
# 1    9.14000     7.33200     12.17280  42.00000   4.96750            0
# 2   46.19856    46.19856     46.19856  46.19856  46.19856            0
# 3    2.94000     9.26800     11.26720  45.00000   6.06500            1
# 4    5.33000     8.82400     11.28960  55.00000   6.06250            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
lm_multi = sn.OLS(y_multi,x_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     84.52
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):          2.87e-125
# Time:                        01:08:47   Log-Likelihood:                -1522.9
# No. Observations:                 506   AIC:                             3078.
# Df Residuals:                     490   BIC:                             3145.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...
